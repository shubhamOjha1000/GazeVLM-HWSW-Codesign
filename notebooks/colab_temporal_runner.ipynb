# %%
# Cell 1 — clone + install
# !git clone https://github.com/<you>/GazeVLM-HWSW-Codesign.git
# %cd GazeVLM-HWSW-Codesign
# !pip -q install -r requirements.txt

# Cell 2 — mount Drive
from google.colab import drive; drive.mount('/content/drive')

# Cell 3 — run the temporal CSV builder (paths -> Drive, so code stays location-agnostic)
# !bash scripts/run_temporal_csv.sh
